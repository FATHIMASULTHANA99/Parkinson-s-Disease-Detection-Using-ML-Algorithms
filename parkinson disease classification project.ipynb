# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('parkinsons.csv')
df.head()
# Out:
#              name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0  phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1  phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2  phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3  phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4  phon_R01_S01_5      116.014       141.781       110.655         0.01284
#
#    MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  ...  \
# 0           0.00007   0.00370   0.00554     0.01109       0.04374  ...
# 1           0.00008   0.00465   0.00696     0.01394       0.06134  ...
# 2           0.00009   0.00544   0.00781     0.01633       0.05233  ...
# 3           0.00009   0.00502   0.00698     0.01505       0.05492  ...
# 4           0.00011   0.00655   0.00908     0.01966       0.06425  ...
#
#    Shimmer:DDA      NHR     HNR  status      RPDE       DFA   spread1  \
# ...

# %%
df=df.set_index('name')

# %%
df.head()
# Out:
#                 MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# name
# phon_R01_S01_1      119.992       157.302        74.997         0.00784
# phon_R01_S01_2      122.400       148.650       113.819         0.00968
# phon_R01_S01_3      116.682       131.111       111.555         0.01050
# phon_R01_S01_4      116.676       137.871       111.366         0.00997
# phon_R01_S01_5      116.014       141.781       110.655         0.01284
#
#                 MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  \
# name
# phon_R01_S01_1           0.00007   0.00370   0.00554     0.01109
# phon_R01_S01_2           0.00008   0.00465   0.00696     0.01394
# phon_R01_S01_3           0.00009   0.00544   0.00781     0.01633
# phon_R01_S01_4           0.00009   0.00502   0.00698     0.01505
# phon_R01_S01_5           0.00011   0.00655   0.00908     0.01966
#
#                 MDVP:Shimmer  MDVP:Shimmer(dB)  ...  Shimmer:DDA      NHR  \
# ...

# %%
df.shape
# Out:
# (195, 23)

# %% [markdown]
# #### Dataset has 195 rows and 24 columns

# %%
#column names
df.columns
# Out:
# Index(['MDVP:Fo(Hz)', 'MDVP:Fhi(Hz)', 'MDVP:Flo(Hz)', 'MDVP:Jitter(%)',
#        'MDVP:Jitter(Abs)', 'MDVP:RAP', 'MDVP:PPQ', 'Jitter:DDP',
#        'MDVP:Shimmer', 'MDVP:Shimmer(dB)', 'Shimmer:APQ3', 'Shimmer:APQ5',
#        'MDVP:APQ', 'Shimmer:DDA', 'NHR', 'HNR', 'status', 'RPDE', 'DFA',
#        'spread1', 'spread2', 'D2', 'PPE'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 195 entries, phon_R01_S01_1 to phon_R01_S50_6
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   MDVP:Fo(Hz)       195 non-null    float64
#  1   MDVP:Fhi(Hz)      195 non-null    float64
#  2   MDVP:Flo(Hz)      195 non-null    float64
#  3   MDVP:Jitter(%)    195 non-null    float64
#  4   MDVP:Jitter(Abs)  195 non-null    float64
#  5   MDVP:RAP          195 non-null    float64
#  6   MDVP:PPQ          195 non-null    float64
#  7   Jitter:DDP        195 non-null    float64
#  8   MDVP:Shimmer      195 non-null    float64
#  9   MDVP:Shimmer(dB)  195 non-null    float64
#  10  Shimmer:APQ3      195 non-null    float64
#  11  Shimmer:APQ5      195 non-null    float64
#  12  MDVP:APQ          195 non-null    float64
#  13  Shimmer:DDA       195 non-null    float64
#  14  NHR               195 non-null    float64
# ...

# %%
df.isnull().sum()
# Out:
# MDVP:Fo(Hz)         0
# MDVP:Fhi(Hz)        0
# MDVP:Flo(Hz)        0
# MDVP:Jitter(%)      0
# MDVP:Jitter(Abs)    0
# MDVP:RAP            0
# MDVP:PPQ            0
# Jitter:DDP          0
# MDVP:Shimmer        0
# MDVP:Shimmer(dB)    0
# Shimmer:APQ3        0
# Shimmer:APQ5        0
# MDVP:APQ            0
# Shimmer:DDA         0
# NHR                 0
# HNR                 0
# status              0
# RPDE                0
# DFA                 0
# spread1             0
# spread2             0
# D2                  0
# PPE                 0
# dtype: int64

# %% [markdown]
# ### no null values in the dataset

# %%
df.describe()
# Out:
#        MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# count   195.000000    195.000000    195.000000      195.000000
# mean    154.228641    197.104918    116.324631        0.006220
# std      41.390065     91.491548     43.521413        0.004848
# min      88.333000    102.145000     65.476000        0.001680
# 25%     117.572000    134.862500     84.291000        0.003460
# 50%     148.790000    175.829000    104.315000        0.004940
# 75%     182.769000    224.205500    140.018500        0.007365
# max     260.105000    592.030000    239.170000        0.033160
#
#        MDVP:Jitter(Abs)    MDVP:RAP    MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# count        195.000000  195.000000  195.000000  195.000000    195.000000
# mean           0.000044    0.003306    0.003446    0.009920      0.029709
# std            0.000035    0.002968    0.002759    0.008903      0.018857
# min            0.000007    0.000680    0.000920    0.002040      0.009540
# ...

# %% [markdown]
# ### To enhance our comprehension of the variables relevant to Parkinson's disease detection, we should begin by examining the data's internal relationships. Correlation diagrams are a valuable tool for visualizing the associations between various variables and their connections with Parkinson's disease status.

# %%
correlation_matrix = df.corr()

# %%
plt.figure(figsize=(15, 15))  
sns.heatmap(correlation_matrix,annot=True)
# Out:
# <Axes: >

# %%
df['status'].value_counts()
# Out:
# 1    147
# 0     48
# Name: status, dtype: int64

# %% [markdown]
# ### The health status of the subjects is denoted in the 'status' column as follows: '1' indicates Parkinson's disease, while '0' represents a healthy status.

# %% [markdown]
# ## data preprocessing

# %% [markdown]
# splitting data into features and target varibales

# %%
x=df.drop('status', axis=True)
x.head()
# Out:
#                 MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# name
# phon_R01_S01_1      119.992       157.302        74.997         0.00784
# phon_R01_S01_2      122.400       148.650       113.819         0.00968
# phon_R01_S01_3      116.682       131.111       111.555         0.01050
# phon_R01_S01_4      116.676       137.871       111.366         0.00997
# phon_R01_S01_5      116.014       141.781       110.655         0.01284
#
#                 MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  \
# name
# phon_R01_S01_1           0.00007   0.00370   0.00554     0.01109
# phon_R01_S01_2           0.00008   0.00465   0.00696     0.01394
# phon_R01_S01_3           0.00009   0.00544   0.00781     0.01633
# phon_R01_S01_4           0.00009   0.00502   0.00698     0.01505
# phon_R01_S01_5           0.00011   0.00655   0.00908     0.01966
#
#                 MDVP:Shimmer  MDVP:Shimmer(dB)  ...  MDVP:APQ  Shimmer:DDA  \
# ...

# %%
y=df['status']
y.head()
# Out:
# name
# phon_R01_S01_1    1
# phon_R01_S01_2    1
# phon_R01_S01_3    1
# phon_R01_S01_4    1
# phon_R01_S01_5    1
# Name: status, dtype: int64

# %% [markdown]
# ##  feature scaling

# %%
from sklearn.preprocessing import MinMaxScaler
sc=MinMaxScaler()

# %%
x=sc.fit_transform(x)
x
# Out:
# array([[0.18430827, 0.11259173, 0.05481479, ..., 0.58576513, 0.39066128,
#         0.4973096 ],
#        [0.19832685, 0.09493044, 0.2783228 , ..., 0.74133704, 0.47314522,
#         0.67132602],
#        [0.16503854, 0.05912816, 0.26528838, ..., 0.68637091, 0.40881938,
#         0.59668246],
#        ...,
#        [0.50273036, 0.28141298, 0.05072714, ..., 0.34257652, 0.55896743,
#         0.18057983],
#        [0.6428929 , 0.60180655, 0.05427936, ..., 0.45288473, 0.31822198,
#         0.16313677],
#        [0.73327434, 0.32279413, 0.07194837, ..., 0.41509481, 0.50367281,
#         0.21545975]])

# %% [markdown]
# ## Data preparation

# %% [markdown]
# #### we did split our dataset into independent and dependent variables

# %% [markdown]
# #### Now splitting  further into training and testing sets.

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
print('shape of x_train; ',x_train.shape)
print('shape of x_test; ',x_test.shape)
print('shape of y_train; ',y_train.shape)
print('shape of y_test; ',y_test.shape)
# Out:
# shape of x_train;  (156, 22)
# shape of x_test;  (39, 22)
# shape of y_train;  (156,)
# shape of y_test;  (39,)

# %% [markdown]
# ## model building

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.svm import 'SVC'

# %%
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix

# %%
models={'LogisticRegression':LogisticRegression(),
      'GaussianNB':GaussianNB(),
      'DecisionTreeClassifier':DecisionTreeClassifier(),
      'RandomForestClassifier':RandomForestClassifier(),
      'AdaBoostClassifier':AdaBoostClassifier(),
      'GradientBoostingClassifier':GradientBoostingClassifier(),'SVC':SVC()}

# %%
for model_name,model in models.items():
    model.fit(x_train,y_train)
    y_pred=model.predict(x_test)
    accuracy = accuracy_score(y_test, y_pred)
    cm = confusion_matrix(y_test, y_pred)
    report=classification_report(y_test,y_pred)
    print(f"{model_name} Accuracy: {accuracy:.2f}")
    print(cm)
    print(report)
# Out:
# LogisticRegression Accuracy: 0.90
# [[ 3  4]
#  [ 0 32]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.43      0.60         7
#            1       0.89      1.00      0.94        32
#
#     accuracy                           0.90        39
#    macro avg       0.94      0.71      0.77        39
# weighted avg       0.91      0.90      0.88        39
#
# GaussianNB Accuracy: 0.72
# [[ 4  3]
#  [ 8 24]]
#               precision    recall  f1-score   support
#
#            0       0.33      0.57      0.42         7
#            1       0.89      0.75      0.81        32
#
#     accuracy                           0.72        39
#    macro avg       0.61      0.66      0.62        39
# weighted avg       0.79      0.72      0.74        39
#
# DecisionTreeClassifier Accuracy: 0.92
# [[ 5  2]
#  [ 1 31]]
#               precision    recall  f1-score   support
#
#            0       0.83      0.71      0.77         7
# ...
